# %%
from PIL import Image, ImageFont, ImageDraw

img = Image.open('templates/template_1.png')
img= img.convert("RGB")
# font = ImageFont.truetype('/home/awstone/dejavu-fonts-ttf-2.37/ttf/DejaVuSerif.ttf', size=30, encoding='unic')
font = ImageFont.load_default()
draw = ImageDraw.Draw(img)

# draw.text((text_x, text_y), text, font=font)
draw.text((100, 350), 'hello', font=font, fill='black')
img
# Out:
# <PIL.Image.Image image mode=RGB size=417x551>
